# %%
#Import dependencies
import pandas as pd
import requests
import numpy as np
import pprint
import sqlalchemy
from config import token

# Python SQL toolkit and Object Relational Mapper
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
#Import list of cities in the US that will be used for the API calls
cities_csv = pd.read_csv("1000-cities.csv")
cities_df = pd.DataFrame(cities_csv, columns = ["Rank", "City", "State", "Growth From 2000 to 2013", "Population", "Latitude", "Longitude"])
dropped = cities_df.drop(["Rank", "Growth From 2000 to 2013", "Population"], axis = 1)
lat = dropped["Latitude"]
long = dropped["Longitude"]
cities = dropped["City"]
city1 = "New York"
dropped
# Out:
#                     City       State   Latitude   Longitude
# 0    Rancho Palos Verdes  California  33.744461 -118.387017
# 1             Burnsville   Minnesota  44.767742  -93.277723
# 2                Rowlett       Texas  32.902902  -96.563880
# 3                Roswell  New Mexico  33.394266 -104.523024
# 4             Montgomery     Alabama  32.366805  -86.299969
# ..                   ...         ...        ...         ...
# 995           Lewisville       Texas  33.046233  -96.994174
# 996           Farmington  New Mexico  36.728058 -108.218686
# 997               Oakley  California  37.997422 -121.712454
# 998            Palo Alto  California  37.441883 -122.143020
# 999          Springfield      Oregon  44.046236 -123.022029
#
# [1000 rows x 4 columns]

# %%
#DO NOT RUN
#INFO WAS EXPORTED TO A CSV AND CALLED AGAIN

#Creating new dataframe to store information from API calls
air_quality_df = pd.DataFrame(columns = ["City", "AQI", "IDX", "IAQI", "Dominant Pollutant", "Date"])
i= 1


#Looping through cities to get Air Quality data
for city in cities:
    print(f"Processing City {i} | {city}")
    try:
            response = requests.get(f"https://api.waqi.info/feed/{city}/?token={token}").json()
            city_name = response['data']['city']['name']
            aqi = response['data']['aqi']
            idx = response['data']['idx']
            iaqi = response['data']['iaqi']['w']['v']
            pollutant = response['data']['dominentpol']
            date = response['data']['time']['iso']
            air_quality_df = air_quality_df.append({"City": city,
                                                    "AQI": aqi,
                                                    "IDX": idx,
                                                    "IAQI": iaqi,
                                                    "Dominant Pollutant": pollutant,
                                                    "Date": date}, ignore_index = True)
    except:
        print("City not found. Skipping...")
        pass
    i += 1
# Out:
# Processing City 1 | Rancho Palos Verdes
# City not found. Skipping...
# Processing City 2 | Burnsville
# Processing City 3 | Rowlett
# City not found. Skipping...
# Processing City 4 | Roswell
# City not found. Skipping...
# Processing City 5 | Montgomery
# Processing City 6 | Logan
# Processing City 7 | Woburn
# City not found. Skipping...
# Processing City 8 | Allentown
# City not found. Skipping...
# Processing City 9 | Mount Pleasant
# Processing City 10 | Columbus
# City not found. Skipping...
# Processing City 11 | Buffalo
# Processing City 12 | New Berlin
# Processing City 13 | North Richland Hills
# City not found. Skipping...
# Processing City 14 | Lima
# Processing City 15 | Sacramento
# Processing City 16 | Fort Smith
# City not found. Skipping...
# Processing City 17 | East Providence
# Processing City 18 | Urbandale
# Processing City 19 | Mount Vernon
# Processing City 20 | Lakewood
# Processing City 21 | Henderson
# Processing City 22 | Covina
# ...

# %%
#First look at API dataframe
air_quality_df
# Out:
#                City AQI    IDX  IAQI Dominant Pollutant  \
# 0        Burnsville  50   7332   1.8               pm25
# 1        Montgomery  57   7379   1.0               pm25
# 2             Logan  43   4462   1.9                 o3
# 3    Mount Pleasant  39   7416   1.0                 o3
# 4           Buffalo  25   5879   0.1               pm25
# ..              ...  ..    ...   ...                ...
# 568      Greenacres   8   9626   2.0                 o3
# 569         Madison  40   5933   1.0                 o3
# 570       Arlington  43    184   4.6               pm25
# 571      Farmington  67  12876   7.0               pm25
# 572     Springfield  35   8200   0.3               pm25
#
#                           Date
# 0    2020-08-13T19:00:00-06:00
# 1    2020-08-13T18:00:00-06:00
# 2    2020-08-13T19:00:00-06:00
# 3    2020-08-13T16:00:00-05:00
# 4    2020-08-13T20:00:00-04:00
# ..                         ...
# 568  2020-08-13T21:00:00-06:00
# 569  2020-08-13T19:00:00-06:00
# ...

# %%
#Export dataframe to CSV
air_quality_df.to_csv('air_quality.csv', index=False)

# %%
#Reading dataframe back in 
path1 = ("air_quality.csv")
clean_air_quality_df=pd.read_csv(path1)

#Importing Population csv
cities_csv = pd.read_csv("1000-cities.csv")
clean_cities_df = pd.DataFrame(cities_csv, columns = ["Rank", "City", "State", "Growth From 2000 to 2013", "Population", "Latitude", "Longitude"])

# %%
#Merging both CSV files
merged_df = pd.merge(clean_air_quality_df, clean_cities_df, on = "City")
merged_df
# Out:
#                City AQI    IDX  IAQI Dominant Pollutant  \
# 0        Burnsville  30   7332   2.4               pm25
# 1        Montgomery  89   7379   0.3               pm25
# 2             Logan  59   4462   3.0               pm25
# 3    Mount Pleasant  39   7416   1.0                 o3
# 4           Buffalo  19   5879   2.5               pm25
# ..              ...  ..    ...   ...                ...
# 726      Bridgeport  41   7389   2.0               pm25
# 727    Chesterfield  55   8911   0.5               pm25
# 728      Greenacres   8   9626   2.0                 o3
# 729       Arlington  56    184   6.6               pm25
# 730      Farmington  82  12876   7.0               pm25
#
#                           Date  Rank           State  \
# 0    2020-08-13T16:00:00-06:00   572       Minnesota
# 1    2020-08-13T16:00:00-06:00   111         Alabama
# 2    2020-08-13T16:00:00-06:00   764            Utah
# 3    2020-08-13T16:00:00-05:00   446  South Carolina
# ...

# %%
#Drop duplicates
clean_merged_df = merged_df.drop_duplicates()

# %%
#Data cleanup: single out columns desired and creating new dataframe
new_clean_merged_df = clean_merged_df.loc[:,["City", "State", "Population", "AQI", "IDX", "Dominant Pollutant", "Growth From 2000 to 2013"]]
new_clean_merged_df
# Out:
#                City           State  Population AQI    IDX Dominant Pollutant  \
# 0        Burnsville       Minnesota       61434  30   7332               pm25
# 1        Montgomery         Alabama      201332  89   7379               pm25
# 2             Logan            Utah       48913  59   4462               pm25
# 3    Mount Pleasant  South Carolina       74885  39   7416                 o3
# 4           Buffalo        New York      258959  19   5879               pm25
# ..              ...             ...         ...  ..    ...                ...
# 726      Bridgeport     Connecticut      147216  41   7389               pm25
# 727    Chesterfield        Missouri       47749  55   8911               pm25
# 728      Greenacres         Florida       38696   8   9626                 o3
# 729       Arlington           Texas      379577  56    184               pm25
# 730      Farmington      New Mexico       45426  82  12876               pm25
#
#      Growth From 2000 to 2013
# ...

# %%
#Renaming columns
aclean_merged_df = new_clean_merged_df.rename(columns = {"Growth From 2000 to 2013":"Population Growth"})
aclean_merged_df
# Out:
#                City           State  Population AQI    IDX Dominant Pollutant  \
# 0        Burnsville       Minnesota       61434  30   7332               pm25
# 1        Montgomery         Alabama      201332  89   7379               pm25
# 2             Logan            Utah       48913  59   4462               pm25
# 3    Mount Pleasant  South Carolina       74885  39   7416                 o3
# 4           Buffalo        New York      258959  19   5879               pm25
# ..              ...             ...         ...  ..    ...                ...
# 726      Bridgeport     Connecticut      147216  41   7389               pm25
# 727    Chesterfield        Missouri       47749  55   8911               pm25
# 728      Greenacres         Florida       38696   8   9626                 o3
# 729       Arlington           Texas      379577  56    184               pm25
# 730      Farmington      New Mexico       45426  82  12876               pm25
#
#      Population Growth
# ...

# %%
#Creating engine and connection
engine = create_engine(f"postgres://postgres:{password}@localhost:5432/airquality_db")
conn = engine.connect()

# %%
#Make sure connection was working
engine.table_names()
# Out:
# ['AQI_Metrics', 'City_AQI', 'City_IDX']

# %%
#Appending tables to PostgreSQL
aclean_merged_df.to_sql( name = 'AQI_Metrics', con=engine, if_exists ='append')

# %%
#Appending second table
AQI_df = aclean_merged_df.loc[:,["City","Population", "AQI",  "Population Growth"]]
AQI_df.to_sql( name = 'AQI_City', con=engine, index = False)

# %%
#Appending third table
IDX_df = aclean_merged_df.loc[:,["City","Population", "IDX",  "Population Growth"]]
AQI_df.to_sql( name = 'IDX_City', con=engine, index = False)
